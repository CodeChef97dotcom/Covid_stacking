# %%
import tensorflow as tf
from keras import *

model = tf.keras.models.load_model("../input/concatenated-weight/Concatenated_model.h5")

# %%
import cv2
from PIL import Image
import numpy as np

# %%
import numpy as np
from keras.preprocessing import image
img = image.load_img('../input/test-files/COVID-3236.png', target_size = (224, 224))
image1=img
img = image.img_to_array(img)
img = np.expand_dims(img, axis = 0)
img_list=[[img,img,img]]
print((model.predict(img_list)))
# Out:
# [[9.9999595e-01 2.7270619e-06 1.2649053e-06]]

# %%
import matplotlib.pyplot as plt
plt.imshow(image1)

# %%
from keras.models import Model
layer_outputs = [layer.output for layer in model.layers]
activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(img_list)

# %%
def display_activation(activations, col_size, row_size, act_index): 
    activation = activations[act_index]
    activation_index=0
    fig, ax = plt.subplots(row_size, col_size, figsize=(row_size*2.5,col_size*1.5))
    for row in range(0,row_size):
        for col in range(0,col_size):
            ax[row][col].imshow(activation[0, :, :, activation_index], cmap='plasma')
            activation_index += 1

# %%
activation = activations[1]
plt.imshow(activation[0, :, :, 0], cmap='plasma')

# %%
activation = activations[50]
plt.imshow(activation[0, :, :, 0], cmap='plasma')

# %%
activation = activations[100]
plt.imshow(activation[0, :, :, 0], cmap='plasma')

# %%
activation = activations[400]
plt.imshow(activation[0, :, :, 0], cmap='plasma')

# %%
activation = activations[900]
plt.imshow(activation[0, :, :, 0], cmap='plasma')
